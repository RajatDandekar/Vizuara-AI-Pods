# %%
#@title 🎧 Download Narration Audio & Play Introduction
import os as _os
if not _os.path.exists("/content/narration"):
    # !pip install -q gdown
    import gdown
    gdown.download(id="1xlnYBGRuQlZF1vx0jTGgHSlezfWG4ELa", output="/content/narration.zip", quiet=False)
    # !unzip -q /content/narration.zip -d /content/narration
    # !rm /content/narration.zip
    print(f"Loaded {len(_os.listdir('/content/narration'))} narration segments")
else:
    print("Narration audio already loaded.")

from IPython.display import Audio, display
display(Audio("/content/narration/00_00_intro.mp3"))

# %%
#@title 🎧 Listen: Setup Code
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_01_setup_code.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %%
#@title 🎧 Listen: Closing
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_06_closing.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %%
# 🔧 Setup: Run this cell first!
# Check GPU availability and install dependencies

import torch
import sys

# Check GPU
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"✅ GPU available: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    device = torch.device('cpu')
    print("⚠️ No GPU detected. Some cells may run slowly.")
    print("   Go to Runtime → Change runtime type → GPU")

print(f"\n📦 Python {sys.version.split()[0]}")
print(f"🔥 PyTorch {torch.__version__}")

# Set random seeds for reproducibility
import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print(f"🎲 Random seed set to {SEED}")

# %matplotlib inline

# %%
#@title 🎧 Listen: Series Overview
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_02_series_overview.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %% [markdown]
# # Prompt Design Principles — Notebook Series
#
# *A hands-on guide to mastering prompt engineering techniques for production LLM systems*

# %% [markdown]
# ## Welcome to the Prompt Design Principles Series!
#
# This series of 5 interactive notebooks will take you from prompt design fundamentals to building production-grade LLM pipelines. Each notebook builds on the previous one, and by the end you will have a complete toolkit for designing prompts that are reliable, structured, and composable.
#
# ### Prerequisites
#
# - Basic Python knowledge
# - A Claude API key (get one at [console.anthropic.com](https://console.anthropic.com))
# - Curiosity about how to get the best results from LLMs!
#
# ### What You Will Learn
#
# | # | Notebook | Key Concepts | Time |
# |---|----------|-------------|------|
# | 01 | **System Prompts & The Right Altitude** | Prompt quality dimensions, Right Altitude principle, system prompt design | 45 min |
# | 02 | **Few-Shot Learning & In-Context Learning** | Zero-shot vs few-shot, example selection, ordering effects | 55 min |
# | 03 | **Chain-of-Thought Prompting** | CoT reasoning, computational scratchpad, zero-shot vs few-shot CoT | 50 min |
# | 04 | **Structured Output & Prompt Chaining** | JSON/XML output, multi-step chains, gate checks, error propagation | 60 min |
# | 05 | **Prompt Design Capstone** | Decision framework, combining all techniques, end-to-end pipeline | 70 min |
#
# **Total estimated time: ~4.5 hours**

# %%
#@title 🎧 Listen: Learning Path
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_03_learning_path.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %% [markdown]
# ## Learning Path
#
# ```
# 01: System Prompts          ──→ Foundation: How to write good prompts
#         │
#         ▼
# 02: Few-Shot Learning       ──→ Show, don't tell: Teaching by example
#         │
#         ▼
# 03: Chain-of-Thought        ──→ Think aloud: Making models reason step-by-step
#         │
#         ▼
# 04: Structured Output       ──→ Control & compose: Reliable pipelines
#    & Prompt Chaining
#         │
#         ▼
# 05: Capstone                ──→ Everything together: Production-grade system
# ```
#
# Each notebook is self-contained and can be run independently, but we recommend following the order above for the best learning experience.

# %%
#@title 🎧 Listen: Install Deps
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_04_install_deps.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %% [markdown]
# ## Quick Setup
#
# Every notebook needs these dependencies. Run this cell once to install everything:

# %%
# !pip install -q anthropic matplotlib seaborn pandas numpy

import os
print("✅ All dependencies installed!")
print("Make sure to set your ANTHROPIC_API_KEY before running the notebooks.")

# %%
#@title 🎧 Listen: About Series
from IPython.display import Audio, display
import os as _os
_f = "/content/narration/00_05_about_series.mp3"
if _os.path.exists(_f):
    display(Audio(_f))
else:
    print("Run the first cell to download narration audio.")

# %% [markdown]
# ## About This Series
#
# This notebook series accompanies the Vizuara article **"Prompt Design Principles"**, which covers the theory behind each technique. The notebooks focus on **hands-on practice** — you will build, test, and evaluate real prompt designs using the Claude API.
#
# By the end of this series, you will be able to:
# - Write system prompts at the "right altitude"
# - Build few-shot classifiers that outperform zero-shot by 20-30%
# - Use chain-of-thought to dramatically improve reasoning accuracy
# - Design structured outputs for reliable downstream parsing
# - Chain prompts together with gate checks for complex multi-step tasks
# - Combine all techniques into a single production-grade pipeline
#
# Let us get started! Open **Notebook 01** to begin.

# %%
print("🚀 Ready to start! Open 01_system_prompts_and_the_right_altitude.ipynb")
